# %%
#FranceIOI-lv2-Fonctions-Formes_creuses
def ligne(x,txt):
   res = ""
   for i in range(x):
      res += str(txt)
   print(res)

def carre(y,x):
   ligne(x,'#')
# Parce que sinon y'a deux'#' au lieu d'un seul...
   if x == 1:
      for i in range(y-2):
         print('#')
# ...et c'est pas ouf
   else:
      for i in range(y-2):
         print('#' + ' '* (x-2) + '#')
   ligne(x,'#')
 
def triangle(x):
   print('@')
   for i in range(x-2):
      print('@' + ' '*i + '@')
   ligne(x,'@')

ligne(int(input()),'X')
carre(int(input()),int(input()))
triangle(int(input()))

# %%
#Paradigmes_de_programation-Exercice1
def Ex1():
    nb_notes = input,'entrez le nombre de notes'
    notes = input,'entrez les notes sous forme de liste ([note1,note2,note3,etc...])'
    val_min = 69420
    al_max = -69420
    for i in notes:
        if i <= val_min:
            val_min = i
        if i >= val_max:
            val_max = i
    moyenne = 0
    for i in notes:
        moyenne += i
    moyenne = moyenne/nb_notes
    return val_min,val_max,moyenne
